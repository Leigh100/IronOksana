# %% [markdown]
# **Activity 3 (Wednesday)**
# As a reminder the objective of this study is to predict the total claim amount of a customer and study/investigate the impact of the factors (input features) on the target variable(total claim amount). That means in your exploratory data analysis, you have to look for patterns in this data that shows interesting relationships among the input features as well as with relation to the target feature.
#
# 1.Get the numeric data into dataframe called numerical and categorical columns in a dataframe called categoricals. (You can use np.number and np.object to select the numerical data types and categorical data types respectively)
# 2. Now we will try to check the normality of the numerical variables visually
# 2.1. Use seaborn library to construct distribution plots for the numerical variables
# 2.2. Use Matplotlib to construct histograms.
# 2.3. Do the distributions for different numerical variables look like a normal distribution?
# 3. For the numerical variables, check for correlation between the input features. Note: this does not include the target feature.
# 4. Plot the Correlation Heatmap.
# 5. (Optional): Drop one of the two features that show a high correlation between them (greater than 0.9). If there is no pair of features that have a high correlation, then do not drop any features.

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('Data_Marketing_Customer_Analysis_Round3.csv')
df
# Out:
#             region  customer_lifetime_value response  coverage education  \
# 0          central                     4809       no     basic   college
# 1      west region                     2228       no     basic   college
# 2             east                    14947       no     basic  bachelor
# 3       north west                    22332      yes  extended   college
# 4       north west                     9025       no   premium  bachelor
# ...            ...                      ...      ...       ...       ...
# 10684      central                    15563       no   premium  bachelor
# 10685   north west                     5259       no     basic   college
# 10686      central                    23893       no  extended  bachelor
# 10687  west region                    11971       no   premium   college
# 10688      central                     6857       no     basic  bachelor
#
#       effective_to_date month employment_status gender  income  ...  \
# ...

# %% [markdown]
# **1.Get the numeric data into dataframe called numerical and categorical columns in a dataframe called categoricals. (You can use np.number and np.object to select the numerical data types and categorical data types respectively)**

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numerical_df = df.select_dtypes(include=numerics)
numerical_df
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                         4809   48029                    61
# 1                         2228   92260                    64
# 2                        14947   22139                   100
# 3                        22332   49078                    97
# 4                         9025   23675                   117
# ...                        ...     ...                   ...
# 10684                    15563   61541                   253
# 10685                     5259   61146                    65
# 10686                    23893   39837                   201
# 10687                    11971   64195                   158
# 10688                     6857   68942                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                            7                             52
# 1                            3                             26
# ...

# %%
numerical_df=df.select_dtypes(include=np.number)
numerical_df
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                         4809   48029                    61
# 1                         2228   92260                    64
# 2                        14947   22139                   100
# 3                        22332   49078                    97
# 4                         9025   23675                   117
# ...                        ...     ...                   ...
# 10684                    15563   61541                   253
# 10685                     5259   61146                    65
# 10686                    23893   39837                   201
# 10687                    11971   64195                   158
# 10688                     6857   68942                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                            7                             52
# 1                            3                             26
# ...

# %%
categorical_df=df.select_dtypes(include=np.object)
categorical_df
# Out:
#             region response  coverage education effective_to_date month  \
# 0          central       no     basic   college           2/18/11   feb
# 1      west region       no     basic   college           1/18/11   jan
# 2             east       no     basic  bachelor           2/10/11   feb
# 3       north west      yes  extended   college           1/11/11   jan
# 4       north west       no   premium  bachelor           1/17/11   jan
# ...            ...      ...       ...       ...               ...   ...
# 10684      central       no   premium  bachelor           1/19/11   jan
# 10685   north west       no     basic   college            1/6/11   jan
# 10686      central       no  extended  bachelor            2/6/11   feb
# 10687  west region       no   premium   college           2/13/11   feb
# 10688      central       no     basic  bachelor            1/8/11   jan
#
#       employment_status gender location_code marital_status     policy_type  \
# ...

# %%
numerical_df.to_csv('Numerical.csv', index =False)

# %%
categorical_df.to_csv('Categorical.csv', index =False)

# %% [markdown]
# 2. Now we will try to check the normality of the numerical variables visually
# a) Use seaborn library to construct distribution plots for the numerical variables
# b) Use Matplotlib to construct histograms.
# c) Do the distributions for different numerical variables look like a normal distribution?

# %% [markdown]
# 2.1 Use seaborn library to construct distribution plots for the numerical variables

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import numpy as np
import pandas as pd



df = pd.read_csv('Numerical.csv')
df
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                         4809   48029                    61
# 1                         2228   92260                    64
# 2                        14947   22139                   100
# 3                        22332   49078                    97
# 4                         9025   23675                   117
# ...                        ...     ...                   ...
# 10684                    15563   61541                   253
# 10685                     5259   61146                    65
# 10686                    23893   39837                   201
# 10687                    11971   64195                   158
# 10688                     6857   68942                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                            7                             52
# 1                            3                             26
# ...

# %%
sns.displot(df, x="customer_lifetime_value")
sns.displot(df, x="income")
sns.displot(df, x="monthly_premium_auto")
sns.displot(df, x="months_since_last_claim")
sns.displot(df, x="months_since_policy_inception")
sns.displot(df, x="number_of_open_complaints")
sns.displot(df, x="number_of_policies")
sns.displot(df, x="total_claim_amount")

# %% [markdown]
# 2.2 Use Matplotlib to construct histograms.

# %%
#fig,axes = plt.subplots(1,2,figsize = (20,6))

df.hist(column='customer_lifetime_value')
df.hist(column='income')
df.hist(column='monthly_premium_auto')
df.hist(column='months_since_last_claim')
df.hist(column='months_since_policy_inception')
df.hist(column='number_of_open_complaints')
df.hist(column='number_of_policies')
df.hist(column='total_claim_amount')
# Out:
# array([[<AxesSubplot:title={'center':'total_claim_amount'}>]],
#       dtype=object)

# %% [markdown]
# 2.3 Do the distributions for different numerical variables look like a normal distribution?

# %% [markdown]
# Distributions for different numerical variables do not look normal.

# %% [markdown]
# 3. For the numerical variables, check for correlation between the input features. Note: this does not include the target feature.

# %%
df[['income','monthly_premium_auto']].corr()
# Out:
#                         income  monthly_premium_auto
# income                1.000000             -0.002431
# monthly_premium_auto -0.002431              1.000000

# %%
df.corr()
# Out:
#                                customer_lifetime_value    income  \
# customer_lifetime_value                       1.000000  0.003732
# income                                        0.003732  1.000000
# monthly_premium_auto                          0.404235 -0.002431
# months_since_last_claim                       0.011912 -0.026564
# months_since_policy_inception                 0.017055  0.003846
# number_of_open_complaints                    -0.032371  0.018903
# number_of_policies                            0.016789 -0.004461
# total_claim_amount                            0.232849 -0.111221
#
#                                monthly_premium_auto  months_since_last_claim  \
# customer_lifetime_value                    0.404235                 0.011912
# income                                    -0.002431                -0.026564
# monthly_premium_auto                       1.000000                 0.010036
# ...

# %% [markdown]
# 4. Plot the Correlation Heatmap.

# %%
fig=plt.figure(figsize=(8,5))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
fig=plt.figure(figsize=(8,5))
sns.heatmap(df[['income','monthly_premium_auto']].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Practising

# %%
sns.scatterplot(x=df.income,y=df.number_of_open_complaints)
# Out:
# <AxesSubplot:xlabel='income', ylabel='number_of_open_complaints'>
