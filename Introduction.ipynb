# %% [markdown]
# Introducing holidays preferences

# %%
x=input('Please enter your name: ')
# Out:
# Please enter your name: Oksana

# %%
from IPython import display
display.Image("https://imgnew.outlookindia.com/uploadimage/library/16_9/16_9_5/IMAGE_1655215200.jpg")

# %%
from IPython import display
display.Image("https://a.cdn-hotels.com/gdcs/production115/d1326/a5981c45-4f4d-44b8-a581-d9b10985fcb7.jpg")

# %% [markdown]
# The person likes to:
# * swim
# * explore the nature
# * explore thai culture

# %% [markdown]
# I used:
# * input function
# * IPython library
# * display image function
