# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("Data_Marketing_Customer_Analysis_Round3 (1).csv")
data
# Out:
#        Unnamed: 0       region  customer_lifetime_value response  coverage  \
# 0               0      central                     4809       no     basic
# 1               1  west region                     2228       no     basic
# 2               2         east                    14947       no     basic
# 3               3   north west                    22332      yes  extended
# 4               4   north west                     9025       no   premium
# ...           ...          ...                      ...      ...       ...
# 10684       10684      central                    15563       no   premium
# 10685       10685   north west                     5259       no     basic
# 10686       10686      central                    23893       no  extended
# 10687       10687  west region                    11971       no   premium
# 10688       10688  west region                     6857       no     basic
#
# ...

# %%
data.drop(labels=['Unnamed: 0'],axis=1,inplace=True)
data
# Out:
#             region  customer_lifetime_value response  coverage education  \
# 0          central                     4809       no     basic   college
# 1      west region                     2228       no     basic   college
# 2             east                    14947       no     basic  bachelor
# 3       north west                    22332      yes  extended   college
# 4       north west                     9025       no   premium  bachelor
# ...            ...                      ...      ...       ...       ...
# 10684      central                    15563       no   premium  bachelor
# 10685   north west                     5259       no     basic   college
# 10686      central                    23893       no  extended  bachelor
# 10687  west region                    11971       no   premium   college
# 10688  west region                     6857       no     basic  bachelor
#
#       effective_to_date month employment_status gender  income  ...  \
# ...

# %%
data = data[data.total_claim_amount != 0]
data
# Out:
#             region  customer_lifetime_value response  coverage education  \
# 0          central                     4809       no     basic   college
# 1      west region                     2228       no     basic   college
# 2             east                    14947       no     basic  bachelor
# 3       north west                    22332      yes  extended   college
# 4       north west                     9025       no   premium  bachelor
# ...            ...                      ...      ...       ...       ...
# 10684      central                    15563       no   premium  bachelor
# 10685   north west                     5259       no     basic   college
# 10686      central                    23893       no  extended  bachelor
# 10687  west region                    11971       no   premium   college
# 10688  west region                     6857       no     basic  bachelor
#
#       effective_to_date month employment_status gender  income  ...  \
# ...

# %%
print(data.keys())
# Out:
# Index(['region', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'month', 'employment_status',
#        'gender', 'income', 'location_code', 'marital_status',
#        'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
#Defined X,y droped some columns, including target feature
X = data.drop(columns=['effective_to_date','total_claim_amount'], axis = 1)
y = np.log(data['total_claim_amount']) # np.where(data["total_claim_amount"]>0,np.log(data['total_claim_amount']),0)

# %%
#Data splitting
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=32)

X_train = pd.DataFrame(X_train, columns=X.columns)
X_test  = pd.DataFrame(X_test, columns=X.columns)

# %%
X_train.head()
# Out:
#           region  customer_lifetime_value response  coverage  \
# 1417     central                     3241       no  extended
# 8487     central                     5838       no     basic
# 7596     central                     8658       no     basic
# 3782  north west                     4726       no     basic
# 3357     central                     2871       no     basic
#
#                  education month employment_status gender  income  \
# 1417              bachelor   jan          employed      f   89196
# 8487               college   feb          employed      f   55419
# 7596               college   feb          employed      m   62464
# 3782  high school or below   jan        unemployed      m   63150
# 3357               college   jan          employed      m   94178
#
#      location_code  ... months_since_last_claim  \
# 1417         rural  ...                      17
# 8487         rural  ...                      31
# 7596         urban  ...                      23
# ...

# %%
X_train.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              7476.000000   7476.000000           7476.000000
# mean               7919.907303  51909.450910             92.991974
# std                6681.751680  25034.231451             33.829823
# min                1898.000000  10037.000000             61.000000
# 25%                4016.750000  29210.000000             68.000000
# 50%                5760.000000  50106.500000             83.000000
# 75%                8916.250000  73054.000000            109.000000
# max               73225.000000  99981.000000            298.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count              7476.000000                    7476.000000
# mean                 15.214821                      48.340289
# std                  10.141903                      28.030376
# min                   0.000000                       0.000000
# ...

# %%
# Variance threshold method
# Univariate method

from sklearn.feature_selection import VarianceThreshold # It only works with numerical features


X_train = X_train.select_dtypes(include=np.number)
X_test  = X_test.select_dtypes(include=np.number)

#display(X_train)
print("Initial number of numerical columns: ",X_train.shape)
print()

selector = VarianceThreshold(threshold=100) # Default threshold value is 0
# Features with a training-set variance lower than this threshold will be removed.
selector.fit(X_train)

kept_features_indexes = selector.get_support(indices = True) #returns an array of integers corresponding to nonremoved features
kept_features = list(X_train.iloc[:,kept_features_indexes].columns)

X_train = selector.transform(X_train)
X_test  = selector.transform(X_test)

X_train = pd.DataFrame(X_train, columns=kept_features)
X_test  = pd.DataFrame(X_test, columns=kept_features)

print("Final number of numerical columns: ",X_train.shape)
print()
X_train
# Out:
# Initial number of numerical columns:  (7476, 5)
#
# Final number of numerical columns:  (7476, 5)
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                        3241   89196                    81
# 1                        5838   55419                    72
# 2                        8658   62464                   109
# 3                        4726   63150                    64
# 4                        2871   94178                    72
# ...                       ...     ...                   ...
# 7471                     3808   94903                    94
# 7472                     4212   10097                   110
# 7473                     2596   42793                    72
# 7474                    24261   66525                   100
# 7475                    15477   51675                   196
#
#       months_since_last_claim  months_since_policy_inception
# 0                          17                             52
# ...

# %%
X_train
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                        3241   89196                    81
# 1                        5838   55419                    72
# 2                        8658   62464                   109
# 3                        4726   63150                    64
# 4                        2871   94178                    72
# ...                       ...     ...                   ...
# 7471                     3808   94903                    94
# 7472                     4212   10097                   110
# 7473                     2596   42793                    72
# 7474                    24261   66525                   100
# 7475                    15477   51675                   196
#
#       months_since_last_claim  months_since_policy_inception
# 0                          17                             52
# 1                          31                             45
# ...

# %%
# Correlation matrix
# Univariate method
import seaborn as sns
import matplotlib.pyplot as plt

c = abs(data.corr())
#c

#fig, ax = plt.subplots(figsize=(14,14))
#sns.heatmap(c, annot=True);
# Correlation heatmap

#c['SalePrice']
c_last = c['total_claim_amount'].sort_values(ascending=False)
#c_last
c_thr = .3
cols_to_keep = list(c_last[c_last > c_thr].index)[1:] + [list(c_last[c_last > c_thr].index)[0]]
print(cols_to_keep)

data[cols_to_keep]
# Out:
# ['monthly_premium_auto', 'total_claim_amount']
#        monthly_premium_auto  total_claim_amount
# 0                        61                 292
# 1                        64                 744
# 2                       100                 480
# 3                        97                 484
# 4                       117                 707
# ...                     ...                 ...
# 10684                   253                1214
# 10685                    65                 273
# 10686                   201                 381
# 10687                   158                 618
# 10688                   101                1021
#
# [10680 rows x 2 columns]

# %%
#Recursive feature elimination
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE  ## recursive feature elemination technique

#We do train/test split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

#We chose only numerical variables
X_train = X_train.select_dtypes(include=np.number)
X_test  = X_test.select_dtypes(include=np.number)

X_train = pd.DataFrame(X_train, columns=X.columns)
X_test  = pd.DataFrame(X_test, columns=X.columns)

#X_train.isna().sum()
nulls = pd.DataFrame(X_train.isna().sum()).reset_index()
#nulls.head()
nulls.columns = ['Column','nas']
#nulls.head()
#nulls[nulls['nas'] > 0].head()
#Get rid of na values
cols_to_drop = nulls[nulls['nas'] > 0]['Column'] # Too drastic, but made on pourpose for quick filtering (don't do this in production!!)

X_train.drop(columns=cols_to_drop, axis=1, inplace = True)
X_test.drop(columns=cols_to_drop, axis=1, inplace = True)

#display(X_train)

lm = LinearRegression()

#Linear model and feauters to select = 8, the number of features I want to keep at the end. 8 Features are selected.
selector = RFE(lm, n_features_to_select= 5, step = 1, verbose = 1) # Step is how many features to add or drop everytime
selector.fit(X_train, y_train)

kept_features = selector.get_support(indices = True) #returns an array of integers corresponding to nonremoved features
kept_features = list(X_train.iloc[:,kept_features].columns)

X_train = selector.transform(X_train)
X_test  = selector.transform(X_test)

X_train = pd.DataFrame(X_train, columns=kept_features)
X_test  = pd.DataFrame(X_test, columns=kept_features)

print("Final selected features: ")
display(X_train)
# Out:
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Final selected features:
#       monthly_premium_auto  months_since_last_claim  \
# 0                       68                       14
# 1                      111                        1
# 2                       74                       35
# 3                       68                        7
# 4                       66                        5
# ...                    ...                      ...
# 8539                    70                       34
# 8540                    61                        6
# 8541                    66                        6
# 8542                   106                       23
# 8543                   199                        5
#
#       months_since_policy_inception  number_of_open_complaints  \
# 0                                46                          0
# 1                                50                          0
# ...

# %%
X_train
# Out:
# array([[2.5560e+03, 2.3867e+04, 6.5000e+01, ..., 9.9000e+01, 0.0000e+00,
#         1.0000e+00],
#        [8.3820e+03, 1.9683e+04, 1.1700e+02, ..., 4.1000e+01, 1.0000e+00,
#         9.0000e+00],
#        [8.6240e+03, 4.3610e+04, 1.0600e+02, ..., 6.0000e+01, 0.0000e+00,
#         5.0000e+00],
#        ...,
#        [2.3960e+03, 9.5718e+04, 6.6000e+01, ..., 7.1000e+01, 2.0000e+00,
#         1.0000e+00],
#        [1.2941e+04, 7.7060e+04, 1.0600e+02, ..., 9.0000e+01, 0.0000e+00,
#         2.0000e+00],
#        [8.0190e+03, 5.4702e+04, 1.9900e+02, ..., 4.2000e+01, 0.0000e+00,
#         1.0000e+00]])

# %%
#Embedded Methods
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

X_train = X_train.select_dtypes(include=np.number)
X_test  = X_test.select_dtypes(include=np.number)

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
X_train=imp_mean.fit_transform(X_train)
X_test = imp_mean.fit_transform(X_test)

# %%
y_train
# Out:
# 2373    5.743003
# 2442    6.329721
# 5403    6.230481
# 3465    5.843544
# 2758    6.291569
#           ...
# 5738    4.990433
# 5195    5.955837
# 5394    6.070738
# 860     6.148468
# 7277    6.861711
# Name: total_claim_amount, Length: 7476, dtype: float64

# %%
#OLS
model=LinearRegression() 
model.fit(X_train, y_train) #fit the model
print(f"{model.__class__.__name__}: Train -> {model.score(X_train, y_train)}, Test -> {model.score(X_test, y_test)}")
# Out:
# LinearRegression: Train -> 0.16766603054887708, Test -> 0.1495634651011326

# %%
#Lasso regression
from sklearn.linear_model import Lasso,Ridge,ElasticNet, LinearRegression
model=Lasso(alpha=0.05)  #alpha =0

model.fit(X_train, y_train)
print(f"{model.__class__.__name__}: Train -> {model.score(X_train, y_train)}, Test -> {model.score(X_test, y_test)}")
# Out:
# Lasso: Train -> 0.16760578771100454, Test -> 0.15011345032271717

# %%
#Ridge
model=Ridge(alpha=10000) #alpha=0
model.fit(X_train, y_train)
print(f"{model.__class__.__name__}: Train -> {model.score(X_train, y_train)}, Test -> {model.score(X_test, y_test)}")
# Out:
# Ridge: Train -> 0.1676568461273853, Test -> 0.14966869385899506

# %% [markdown]
# **There is no difference in performance between LinearRegression, Lasso and Ridge models.**

# %%
#ElasticNet
model=ElasticNet(alpha=0.1)
model.fit(X_train, y_train)
print(f"{model.__class__.__name__}: Train -> {model.score(X_train, y_train)}, Test -> {model.score(X_test, y_test)}")
# Out:
# ElasticNet: Train -> 0.16760560868581664, Test -> 0.15011460738104776
